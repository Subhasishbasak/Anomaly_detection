# %%
import pandas as pd

# %%
data = pd.read_csv("resources/Data.csv")

# %%
data.head()
# Out:
#       QTR          AC6        AC6.1        AC6.2        AC6.3          AC5  \
# 0     NaN          V61          V62          V63          V64         V521
# 1     NaN   NOTCHECKED   NOTCHECKED      CHECKED   NOTCHECKED   NOTCHECKED
# 2  2007Q1  14.83701892  99.39895748  62.94080546      101.764  1.674048473
# 3  2007Q2  14.90709017  91.33259965  58.44709848  101.1369231  3.004369667
# 4  2007Q3  23.21522878  117.8079253  87.46058542  98.30738462  2.909346725
#
#          AC5.1        AC6.4        AC6.5        AC6.6     ...      \
# 0          V56          V65          V66          V67     ...
# 1   NOTCHECKED   NOTCHECKED   NOTCHECKED   NOTCHECKED     ...
# 2   3.82953486  1.376969231  1.734046154  1.734892308     ...
# 3   3.82953486  1.400923077  1.547769231  1.698153846     ...
# 4  3.342410308  2.126230769  1.973061538  2.402969231     ...
#
#         AC6.16       AC6.17       AC6.18       AC6.19       AC6.20  \
# ...

# %%
data.tail()
# Out:
#        QTR          AC6        AC6.1        AC6.2        AC6.3          AC5  \
# 45  2017Q4  26.77706359  87.38908844  80.87404455  103.4492308  3.004369667
# 46  2018Q1  27.55242244  93.06804347  83.96360027  99.42338462  2.909346725
# 47  2018Q2  31.55370752  124.5610248  92.46604632  96.05646154  4.809805574
# 48  2018Q3  36.29519543  138.1344746    100.21073  95.69953846  4.049622034
# 49  2018Q4  39.42892285  144.1578068  108.4627353         94.2  2.909346725
#
#           AC5.1        AC6.4        AC6.5        AC6.6     ...      \
# 45  3.899124082  2.036861538  2.716569231  2.373630769     ...
# 46  3.342410308  2.003046154  2.467076923  2.174646154     ...
# 47  5.638854625  2.259230769  2.824384615  2.485492308     ...
# 48  3.759945638  2.588092308  2.999815385  2.737523077     ...
# 49  3.203231865  2.714560606  3.111424242  2.849590909     ...
#
#          AC6.16       AC6.17       AC6.18       AC6.19       AC6.20  \
# ...

# %%
data.shape
# Out:
# (50, 78)
